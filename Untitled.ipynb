# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import analyze # takes some time since inits hax
from channel_dict import channel_dict
from tqdm import tqdm
import datetime
import pickle
from scipy.stats import norm
import shutil

# %matplotlib inline

# %%
thresholds = np.load('selftrigger_thresholds_SR1_after6846.npz')['thresholds']

# %%
x, acc, errs = analyze.acceptance_curve_3runs(18190, 18191, 18192)

# %%
plt.figure(figsize=(9,6))
for ch in range(248):
    plt.plot(x, acc[ch], color='k', alpha=0.5)

plt.xlim(0,100)
# Out:
# (0, 100)

# %%
acc_frac, acc_errs, sys_errs, stat_errs = analyze.acceptance_fraction(18190, thresholds)

# %%
print(acc_frac.shape)
print(acc_errs.shape)
print(sys_errs.shape)
print(stat_errs.shape)
# Out:
# (248,)
# (2, 248, 1099)
# (248,)
# (2, 248, 1099)

# %%
acc, errs, sys, stat = analyze.acceptance_3runs(18190, 18191, 18192, thresholds)

# %%
for arr in [acc, errs, sys, stat]:
    print(
# Out:
# (248,)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-bbeda8479d18> in <module>()
#       1 for arr in [acc, errs, sys, stat]:
# ----> 2     print(arr.shape)
#
# AttributeError: 'list' object has no attribute 'shape'
